# %%
import pandas as pd
from datetime import date

# %%
weather_df = pd.read_csv('weather.csv')

# %%
station_df = pd.read_csv('station.csv')

# %%
trip_df = pd.read_csv('trip.csv', error_bad_lines=False)
# Out:
# /home/marie/401/bike-stats/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %%
trip_df.head(1)
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype gender  birthyear
# 0          CBD-06         PS-04   Member   Male     1960.0

# %%
weather_df.head(1)
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
#
#    Mean_Humidity  Min_Humidity  ...  Mean_Sea_Level_Pressure_In  \
# 0             68            46  ...                       29.79
#
#    Min_Sea_Level_Pressure_In  Max_Visibility_Miles  Mean_Visibility_Miles  \
# 0                      29.65                    10                     10
#
#    Min_Visibility_Miles  Max_Wind_Speed_MPH  Mean_Wind_Speed_MPH  \
# 0                     4                  13                    4
#
#    Max_Gust_Speed_MPH Precipitation_In  Events
# 0                  21              0.0    Rain
#
# [1 rows x 21 columns]

# %%
station_df.head(10)
# Out:
#   station_id                            name        lat        long  \
# 0      BT-01              3rd Ave & Broad St  47.618418 -122.350964
# 1      BT-03               2nd Ave & Vine St  47.615829 -122.348564
# 2      BT-04          6th Ave & Blanchard St  47.616094 -122.341102
# 3      BT-05          2nd Ave & Blanchard St  47.613110 -122.344208
# 4     CBD-03              7th Ave & Union St  47.610731 -122.332447
# 5     CBD-04              Union St & 4th Ave  47.609221 -122.335596
# 6     CBD-05             1st Ave & Marion St  47.604058 -122.335800
# 7     CBD-06             2nd Ave & Spring St  47.605950 -122.335768
# 8     CBD-07  City Hall / 4th Ave & James St  47.603509 -122.330409
# 9     CBD-13               2nd Ave & Pine St  47.610185 -122.339641
#
#   install_date  install_dockcount modification_date  current_dockcount  \
# 0   10/13/2014                 18               NaN                 18
# 1   10/13/2014                 16               NaN                 16
# ...

# %%
# What is the average trip duration for a borrowed bicycle?

trip_df.tripduration.mean()
# Out:
# 1178.2956753399776

# %%
# What’s the most common age of a bicycle-sharer?
birth_year = trip_df.birthyear.mode()
current_year = date.today().year
current_year - birth_year
# Out:
# 0    34.0
# dtype: float64

# %%
# Given all the weather data here, find the average precipitation per month, and the median precipitation.
print(weather_df.Precipitation_In.mean(), 'inches')
print(weather_df.Precipitation_In.median(), 'inches')
# Out:
# 0.10506531204644412 inches
# 0.0 inches

# %%
weather_df.groupby('Date').Precipitation_In.mean()
# Out:
# Date
# 1/1/2015     0.00
# 1/1/2016     0.00
# 1/10/2015    0.18
# 1/10/2016    0.00
# 1/11/2015    0.06
#              ...
# 9/5/2015     0.06
# 9/6/2015     0.19
# 9/7/2015     0.00
# 9/8/2015     0.00
# 9/9/2015     0.00
# Name: Precipitation_In, Length: 689, dtype: float64

# %%
# What’s the average number of bikes at a given bike station?
round(station_df['current_dockcount'].mean())
# Out:
# 17

# %%
# When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?
# Lose - there's more current counts less than install counts than vice versa
station_df[['modification_date', 'install_dockcount', 'current_dockcount']].dropna()

# station_df.install_dockcount > station_df.current_dockcount
# Out:
#    modification_date  install_dockcount  current_dockcount
# 7          11/9/2015                 20                 18
# 10          8/9/2016                 16                  0
# 12         2/24/2015                 18                 20
# 17         2/24/2015                 28                 26
# 22         3/24/2015                 30                 24
# 23         3/27/2015                 12                 16
# 26         3/18/2016                 16                  0
# 31         2/24/2015                 18                 20
# 35         3/13/2015                 12                 20
# 37         2/23/2015                 18                 16
# 38         11/2/2015                 20                  0
# 39          3/4/2015                 12                 16
# 46        10/29/2015                 16                  0
# 47         2/20/2015                 12                 14
# 48         2/20/2015                 18                 16
# ...

# %%
# Whats the minimum amount of bike doc installations.

station_df.install_dockcount.min()
# Out:
# 12

# %%
# Whats the maximum amount of bike doc installations.

station_df.install_dockcount.max()
# Out:
# 30

# %%
# Which stations have a doc count of 20?
station_df[station_df.install_dockcount == 20]
# Out:
#    station_id                                           name        lat  \
# 4      CBD-03                             7th Ave & Union St  47.610731
# 6      CBD-05                            1st Ave & Marion St  47.604058
# 7      CBD-06                            2nd Ave & Spring St  47.605950
# 8      CBD-07                 City Hall / 4th Ave & James St  47.603509
# 27      FH-04  Seattle University / E Columbia St & 12th Ave  47.609239
# 36     SLU-16                              Pine St & 9th Ave  47.613715
# 38     SLU-18                         Dexter Ave & Denny Way  47.618285
# 40     SLU-20                         Terry Ave & Stewart St  47.616260
# 41     SLU-21                          Mercer St & 9th Ave N  47.624769
# 50      UW-07              UW Intramural Activities Building  47.653713
#
#           long install_date  install_dockcount modification_date  \
# 4  -122.332447   10/13/2014                 20               NaN
# ...
